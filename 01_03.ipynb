# %%
# I set the key using export GEMINI_API_KEY="your_api_key_here" on the terminal
# Key was generated at https://ai.google.dev/gemini-api/docs - https://aistudio.google.com/api-keys

# ADK First Steps: Quickstart
# Welcome 👋🏻 In this tutorial, you'll embark on your journey with Google's Agent Development Kit (ADK).
# We'll cover the essentials: installing the ADK, configuring your environment, defining a simple agent, 

# and running your very first agent interaction.

# %%
# load API Key set in .EnvironmentError
import dotenv
dotenv.load_dotenv()

import os
#import getpass

# Load the Gemini API key from environment variable
# If not set, prompt the user to enter it
api_key = os.environ.get("GEMINI_API_KEY")
if not api_key:
    print("GEMINI_API_KEY not found in environment variables.")
    #api_key = getpass.getpass("Enter your GEMINI_API_KEY: ")
    #os.environ["GEMINI_API_KEY"] = api_key

print("API key configured successfully." if api_key else "Failed to set API key.")
# Out:
# API key configured successfully.

# %%
# Install Google ADK for Python
# This is the foundational package that provides all the necessary components for building and running your agents.
# The --quiet flag suppresses verbose output during installation.
# %pip install google-adk # --quiet
# Out:
# Requirement already satisfied: google-adk in /usr/local/python/3.12.1/lib/python3.12/site-packages (1.18.0)
# Requirement already satisfied: PyYAML<7.0.0,>=6.0.2 in /home/codespace/.local/lib/python3.12/site-packages (from google-adk) (6.0.3)
# Requirement already satisfied: anyio<5.0.0,>=4.9.0 in /home/codespace/.local/lib/python3.12/site-packages (from google-adk) (4.11.0)
# Requirement already satisfied: authlib<2.0.0,>=1.5.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-adk) (1.6.5)
# Requirement already satisfied: click<9.0.0,>=8.1.8 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-adk) (8.3.1)
# Requirement already satisfied: fastapi<1.119.0,>=0.115.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-adk) (0.121.2)
# Requirement already satisfied: google-api-python-client<3.0.0,>=2.157.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-adk) (2.187.0)
# Requirement already satisfied: google-cloud-aiplatform<2.0.0,>=1.125.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (1.127.0)
# Requirement already satisfied: google-cloud-bigtable>=2.32.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-adk) (2.34.0)
# Requirement already satisfied: google-cloud-discoveryengine<0.14.0,>=0.13.12 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-adk) (0.13.12)
# Requirement already satisfied: google-cloud-secret-manager<3.0.0,>=2.22.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-adk) (2.25.0)
# Requirement already satisfied: google-cloud-spanner<4.0.0,>=3.56.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-adk) (3.59.0)
# Requirement already satisfied: google-cloud-speech<3.0.0,>=2.30.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-adk) (2.34.0)
# Requirement already satisfied: google-cloud-storage<4.0.0,>=3.0.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-adk) (3.5.0)
# Requirement already satisfied: google-genai<2.0.0,>=1.45.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-adk) (1.50.1)
# Requirement already satisfied: graphviz<1.0.0,>=0.20.2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-adk) (0.21)
# Requirement already satisfied: mcp<2.0.0,>=1.8.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-adk) (1.21.1)
# Requirement already satisfied: opentelemetry-api<=1.37.0,>=1.37.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-adk) (1.37.0)
# Requirement already satisfied: opentelemetry-exporter-gcp-logging<2.0.0,>=1.9.0a0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-adk) (1.11.0a0)
# Requirement already satisfied: opentelemetry-exporter-gcp-monitoring<2.0.0,>=1.9.0a0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-adk) (1.11.0a0)
# Requirement already satisfied: opentelemetry-exporter-gcp-trace<2.0.0,>=1.9.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-adk) (1.11.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http>=1.36.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-adk) (1.37.0)
# Requirement already satisfied: opentelemetry-resourcedetector-gcp<2.0.0,>=1.9.0a0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-adk) (1.11.0a0)
# Requirement already satisfied: opentelemetry-sdk<=1.37.0,>=1.37.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-adk) (1.37.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-adk) (2.12.4)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.9.0.post0 in /home/codespace/.local/lib/python3.12/site-packages (from google-adk) (2.9.0.post0)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-adk) (1.2.1)
# Requirement already satisfied: requests<3.0.0,>=2.32.4 in /home/codespace/.local/lib/python3.12/site-packages (from google-adk) (2.32.5)
# Requirement already satisfied: sqlalchemy-spanner>=1.14.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-adk) (1.17.1)
# Requirement already satisfied: sqlalchemy<3.0.0,>=2.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-adk) (2.0.44)
# Requirement already satisfied: starlette<1.0.0,>=0.46.2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-adk) (0.49.3)
# Requirement already satisfied: tenacity<10.0.0,>=9.0.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-adk) (9.1.2)
# Requirement already satisfied: typing-extensions<5,>=4.5 in /home/codespace/.local/lib/python3.12/site-packages (from google-adk) (4.15.0)
# Requirement already satisfied: tzlocal<6.0,>=5.3 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-adk) (5.3.1)
# Requirement already satisfied: uvicorn<1.0.0,>=0.34.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-adk) (0.38.0)
# Requirement already satisfied: watchdog<7.0.0,>=6.0.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-adk) (6.0.0)
# Requirement already satisfied: websockets<16.0.0,>=15.0.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-adk) (15.0.1)
# Requirement already satisfied: idna>=2.8 in /home/codespace/.local/lib/python3.12/site-packages (from anyio<5.0.0,>=4.9.0->google-adk) (3.11)
# Requirement already satisfied: sniffio>=1.1 in /home/codespace/.local/lib/python3.12/site-packages (from anyio<5.0.0,>=4.9.0->google-adk) (1.3.1)
# Requirement already satisfied: cryptography in /usr/local/python/3.12.1/lib/python3.12/site-packages (from authlib<2.0.0,>=1.5.1->google-adk) (46.0.3)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from fastapi<1.119.0,>=0.115.0->google-adk) (0.0.4)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk) (0.31.0)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk) (2.43.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk) (0.2.1)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk) (2.28.1)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk) (4.2.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client<3.0.0,>=2.157.0->google-adk) (1.72.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client<3.0.0,>=2.157.0->google-adk) (6.33.1)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client<3.0.0,>=2.157.0->google-adk) (1.26.1)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client<3.0.0,>=2.157.0->google-adk) (6.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client<3.0.0,>=2.157.0->google-adk) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client<3.0.0,>=2.157.0->google-adk) (4.9.1)
# Requirement already satisfied: packaging>=14.3 in /home/codespace/.local/lib/python3.12/site-packages (from google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (25.0)
# Requirement already satisfied: google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (3.38.0)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0,>=1.3.3 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (1.15.0)
# Requirement already satisfied: shapely<3.0.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (2.1.2)
# Requirement already satisfied: docstring_parser<1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (0.17.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from fastapi<1.119.0,>=0.115.0->google-adk) (0.0.4)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk) (0.31.0)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk) (2.43.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk) (0.2.1)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk) (2.28.1)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk) (4.2.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client<3.0.0,>=2.157.0->google-adk) (1.72.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client<3.0.0,>=2.157.0->google-adk) (6.33.1)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client<3.0.0,>=2.157.0->google-adk) (1.26.1)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client<3.0.0,>=2.157.0->google-adk) (6.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client<3.0.0,>=2.157.0->google-adk) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client<3.0.0,>=2.157.0->google-adk) (4.9.1)
# Requirement already satisfied: packaging>=14.3 in /home/codespace/.local/lib/python3.12/site-packages (from google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (25.0)
# Requirement already satisfied: google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (3.38.0)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0,>=1.3.3 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (1.15.0)
# Requirement already satisfied: shapely<3.0.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (2.1.2)
# Requirement already satisfied: docstring_parser<1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (0.17.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (1.76.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (1.76.0)
# Requirement already satisfied: cloudpickle<4.0,>=3.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (3.1.2)
# Requirement already satisfied: google-cloud-trace<2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (1.17.0)
# Requirement already satisfied: google-cloud-logging<4 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (3.12.1)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.4.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0->google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (2.5.0)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.0.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0->google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (2.7.2)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (1.76.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (1.76.0)
# Requirement already satisfied: cloudpickle<4.0,>=3.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (3.1.2)
# Requirement already satisfied: google-cloud-trace<2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (1.17.0)
# Requirement already satisfied: google-cloud-logging<4 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (3.12.1)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.4.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0->google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (2.5.0)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.0.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0->google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (2.7.2)
# Requirement already satisfied: google-cloud-appengine-logging<2.0.0,>=0.1.3 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-cloud-logging<4->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (1.7.0)
# Requirement already satisfied: google-cloud-audit-log<1.0.0,>=0.3.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-cloud-logging<4->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (0.4.0)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0,>=0.12.4 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-cloud-logging<4->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (0.14.3)
# Requirement already satisfied: google-cloud-appengine-logging<2.0.0,>=0.1.3 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-cloud-logging<4->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (1.7.0)
# Requirement already satisfied: google-cloud-audit-log<1.0.0,>=0.3.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-cloud-logging<4->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (0.4.0)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0,>=0.12.4 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-cloud-logging<4->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (0.14.3)
# Requirement already satisfied: sqlparse>=0.4.4 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-cloud-spanner<4.0.0,>=3.56.0->google-adk) (0.5.3)
# Requirement already satisfied: grpc-interceptor>=0.15.4 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-cloud-spanner<4.0.0,>=3.56.0->google-adk) (0.15.4)
# Requirement already satisfied: google-crc32c<2.0.0,>=1.1.3 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-cloud-storage<4.0.0,>=3.0.0->google-adk) (1.7.1)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in /home/codespace/.local/lib/python3.12/site-packages (from google-genai<2.0.0,>=1.45.0->google-adk) (0.28.1)
# Requirement already satisfied: sqlparse>=0.4.4 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-cloud-spanner<4.0.0,>=3.56.0->google-adk) (0.5.3)
# Requirement already satisfied: grpc-interceptor>=0.15.4 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-cloud-spanner<4.0.0,>=3.56.0->google-adk) (0.15.4)
# Requirement already satisfied: google-crc32c<2.0.0,>=1.1.3 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-cloud-storage<4.0.0,>=3.0.0->google-adk) (1.7.1)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in /home/codespace/.local/lib/python3.12/site-packages (from google-genai<2.0.0,>=1.45.0->google-adk) (0.28.1)
# Requirement already satisfied: pyparsing<4,>=3.0.4 in /home/codespace/.local/lib/python3.12/site-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client<3.0.0,>=2.157.0->google-adk) (3.2.5)
# Requirement already satisfied: certifi in /home/codespace/.local/lib/python3.12/site-packages (from httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.45.0->google-adk) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /home/codespace/.local/lib/python3.12/site-packages (from httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.45.0->google-adk) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /home/codespace/.local/lib/python3.12/site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.45.0->google-adk) (0.16.0)
# Requirement already satisfied: httpx-sse>=0.4 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from mcp<2.0.0,>=1.8.0->google-adk) (0.4.3)
# Requirement already satisfied: jsonschema>=4.20.0 in /home/codespace/.local/lib/python3.12/site-packages (from mcp<2.0.0,>=1.8.0->google-adk) (4.25.1)
# Requirement already satisfied: pydantic-settings>=2.5.2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from mcp<2.0.0,>=1.8.0->google-adk) (2.12.0)
# Requirement already satisfied: pyjwt>=2.10.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pyjwt[crypto]>=2.10.1->mcp<2.0.0,>=1.8.0->google-adk) (2.10.1)
# Requirement already satisfied: python-multipart>=0.0.9 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from mcp<2.0.0,>=1.8.0->google-adk) (0.0.20)
# Requirement already satisfied: sse-starlette>=1.6.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from mcp<2.0.0,>=1.8.0->google-adk) (3.0.3)
# Requirement already satisfied: typing-inspection>=0.4.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from mcp<2.0.0,>=1.8.0->google-adk) (0.4.2)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from opentelemetry-api<=1.37.0,>=1.37.0->google-adk) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api<=1.37.0,>=1.37.0->google-adk) (3.23.0)
# Requirement already satisfied: google-cloud-monitoring~=2.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from opentelemetry-exporter-gcp-monitoring<2.0.0,>=1.9.0a0->google-adk) (2.28.0)
# Requirement already satisfied: pyparsing<4,>=3.0.4 in /home/codespace/.local/lib/python3.12/site-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client<3.0.0,>=2.157.0->google-adk) (3.2.5)
# Requirement already satisfied: certifi in /home/codespace/.local/lib/python3.12/site-packages (from httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.45.0->google-adk) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /home/codespace/.local/lib/python3.12/site-packages (from httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.45.0->google-adk) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /home/codespace/.local/lib/python3.12/site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.45.0->google-adk) (0.16.0)
# Requirement already satisfied: httpx-sse>=0.4 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from mcp<2.0.0,>=1.8.0->google-adk) (0.4.3)
# Requirement already satisfied: jsonschema>=4.20.0 in /home/codespace/.local/lib/python3.12/site-packages (from mcp<2.0.0,>=1.8.0->google-adk) (4.25.1)
# Requirement already satisfied: pydantic-settings>=2.5.2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from mcp<2.0.0,>=1.8.0->google-adk) (2.12.0)
# Requirement already satisfied: pyjwt>=2.10.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pyjwt[crypto]>=2.10.1->mcp<2.0.0,>=1.8.0->google-adk) (2.10.1)
# Requirement already satisfied: python-multipart>=0.0.9 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from mcp<2.0.0,>=1.8.0->google-adk) (0.0.20)
# Requirement already satisfied: sse-starlette>=1.6.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from mcp<2.0.0,>=1.8.0->google-adk) (3.0.3)
# Requirement already satisfied: typing-inspection>=0.4.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from mcp<2.0.0,>=1.8.0->google-adk) (0.4.2)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from opentelemetry-api<=1.37.0,>=1.37.0->google-adk) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api<=1.37.0,>=1.37.0->google-adk) (3.23.0)
# Requirement already satisfied: google-cloud-monitoring~=2.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from opentelemetry-exporter-gcp-monitoring<2.0.0,>=1.9.0a0->google-adk) (2.28.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.37.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-http>=1.36.0->google-adk) (1.37.0)
# Requirement already satisfied: opentelemetry-proto==1.37.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-http>=1.36.0->google-adk) (1.37.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.58b0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from opentelemetry-sdk<=1.37.0,>=1.37.0->google-adk) (0.58b0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.37.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-http>=1.36.0->google-adk) (1.37.0)
# Requirement already satisfied: opentelemetry-proto==1.37.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-http>=1.36.0->google-adk) (1.37.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.58b0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from opentelemetry-sdk<=1.37.0,>=1.37.0->google-adk) (0.58b0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.0->google-adk) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.0->google-adk) (2.41.5)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.12/site-packages (from python-dateutil<3.0.0,>=2.9.0.post0->google-adk) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/codespace/.local/lib/python3.12/site-packages (from requests<3.0.0,>=2.32.4->google-adk) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/codespace/.local/lib/python3.12/site-packages (from requests<3.0.0,>=2.32.4->google-adk) (2.5.0)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from rsa<5,>=3.1.4->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client<3.0.0,>=2.157.0->google-adk) (0.6.1)
# Requirement already satisfied: numpy>=1.21 in /home/codespace/.local/lib/python3.12/site-packages (from shapely<3.0.0->google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (2.3.4)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.0->google-adk) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.0->google-adk) (2.41.5)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.12/site-packages (from python-dateutil<3.0.0,>=2.9.0.post0->google-adk) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/codespace/.local/lib/python3.12/site-packages (from requests<3.0.0,>=2.32.4->google-adk) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/codespace/.local/lib/python3.12/site-packages (from requests<3.0.0,>=2.32.4->google-adk) (2.5.0)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from rsa<5,>=3.1.4->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client<3.0.0,>=2.157.0->google-adk) (0.6.1)
# Requirement already satisfied: numpy>=1.21 in /home/codespace/.local/lib/python3.12/site-packages (from shapely<3.0.0->google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (2.3.4)
# Requirement already satisfied: greenlet>=1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from sqlalchemy<3.0.0,>=2.0->google-adk) (3.2.4)
# Requirement already satisfied: greenlet>=1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from sqlalchemy<3.0.0,>=2.0->google-adk) (3.2.4)
# Requirement already satisfied: attrs>=22.2.0 in /home/codespace/.local/lib/python3.12/site-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.8.0->google-adk) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/codespace/.local/lib/python3.12/site-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.8.0->google-adk) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/codespace/.local/lib/python3.12/site-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.8.0->google-adk) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/codespace/.local/lib/python3.12/site-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.8.0->google-adk) (0.28.0)
# Requirement already satisfied: attrs>=22.2.0 in /home/codespace/.local/lib/python3.12/site-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.8.0->google-adk) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/codespace/.local/lib/python3.12/site-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.8.0->google-adk) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/codespace/.local/lib/python3.12/site-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.8.0->google-adk) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/codespace/.local/lib/python3.12/site-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.8.0->google-adk) (0.28.0)
# Requirement already satisfied: cffi>=2.0.0 in /home/codespace/.local/lib/python3.12/site-packages (from cryptography->authlib<2.0.0,>=1.5.1->google-adk) (2.0.0)
# Requirement already satisfied: pycparser in /home/codespace/.local/lib/python3.12/site-packages (from cffi>=2.0.0->cryptography->authlib<2.0.0,>=1.5.1->google-adk) (2.23)
# Requirement already satisfied: alembic in /usr/local/python/3.12.1/lib/python3.12/site-packages (from sqlalchemy-spanner>=1.14.0->google-adk) (1.17.2)
# Requirement already satisfied: cffi>=2.0.0 in /home/codespace/.local/lib/python3.12/site-packages (from cryptography->authlib<2.0.0,>=1.5.1->google-adk) (2.0.0)
# Requirement already satisfied: pycparser in /home/codespace/.local/lib/python3.12/site-packages (from cffi>=2.0.0->cryptography->authlib<2.0.0,>=1.5.1->google-adk) (2.23)
# Requirement already satisfied: alembic in /usr/local/python/3.12.1/lib/python3.12/site-packages (from sqlalchemy-spanner>=1.14.0->google-adk) (1.17.2)
# Requirement already satisfied: Mako in /usr/local/python/3.12.1/lib/python3.12/site-packages (from alembic->sqlalchemy-spanner>=1.14.0->google-adk) (1.3.10)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /home/codespace/.local/lib/python3.12/site-packages (from Mako->alembic->sqlalchemy-spanner>=1.14.0->google-adk) (3.0.3)
# Requirement already satisfied: Mako in /usr/local/python/3.12.1/lib/python3.12/site-packages (from alembic->sqlalchemy-spanner>=1.14.0->google-adk) (1.3.10)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /home/codespace/.local/lib/python3.12/site-packages (from Mako->alembic->sqlalchemy-spanner>=1.14.0->google-adk) (3.0.3)
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.

# %%
# Verify ADK Installation (Optional but Recommended)
# %pip show google-adk

# %%
# Configure environment
import os

# Set GOOGLE_GENAI_USE_VERTEXAI to "False" to use the public Gemini API directly,
# rather than routing through Google Cloud's Vertex AI. This simplifies setup for quick demos.
os.environ["GOOGLE_GENAI_USE_VERTEXAI"] = "False"

# Define the specific Gemini model we'll use. 
# 'gemini-2.0-flash' is a fast and efficient model.
MODEL_GEMINI_2_0_FLASH = "gemini-2.0-flash"

# %%
# Import Necessary Modules

# Agent: The fundamental class for creating an AI agent within ADK.
from google.adk.agents import Agent

# Runner: The orchestrator that manages the flow of messages and agent execution.
from google.adk.runners import Runner

# InMemorySessionService: A simple, in-memory service for managing conversation sessions. 
# Sessions are vital for maintaining context in multi-turn dialogues.
from google.adk.sessions import InMemorySessionService

# types from google.genai: Provides data structures (like Content and Part) to represent messages exchanged with the language model.
from google.genai import types

# %%
# Define Our Simple Greeting Agent
# In ADK, an Agent is defined by its core characteristics and behavior.
# name: A unique identifier for your agent (e.g., "greeting_agent").
# model: The underlying large language model (LLM) that the agent will use for its intelligence (e.g., MODEL_GEMINI_2_0_FLASH).
# description: A short, human-readable summary of the agent's purpose. This is useful for documentation and for other agents if you build multi-agent systems.
# instruction: This is the most critical part! It's the natural language prompt that guides the agent's behavior. 
# We'll instruct our agent to simply greet the user back in the language they used, concisely.

greeting_agent = Agent(
    name="greeting_agent",
    model=MODEL_GEMINI_2_0_FLASH,
    description="An agent whose sole purpose is to greet users back.",
    instruction="""
        You are a dedicated greeting agent.
        Your ONLY response should be a warm, enthusiastic greeting.
        You MUST use the same language of the user's input greeting to greet them back in a warm, enthusiastic manner.
        DO NOT ask follow-up questions, offer assistance, or provide any information beyond the greeting itself.
        Even if the user's input is not a greeting or asks a question, you must still respond ONLY with a warm, enthusiastic greeting.
    """,
)

print("`greeting_agent` successfully defined.")
# Out:
# `greeting_agent` successfully defined.

# %%
# Modular Function for Agent Interaction
async def run_adk_agent_interaction(
    agent: Agent,
    user_id: str,
    session_id: str,
    input_text: str,
    app_name: str = "default_app",
    session_service: InMemorySessionService = None,
) -> str:
    """
    Runs a single interaction with an ADK agent and returns its final text response.

    Args:
        agent: The ADK Agent instance to interact with.
        user_id: A unique identifier for the user initiating the interaction.
        session_id: A unique identifier for the conversation session.
                    Using a new ID for each distinct example ensures isolation.
        input_text: The textual message from the user.
        app_name: The name of the application using the agent. Defaults to "default_app".
        session_service: An optional InMemorySessionService instance. If None, a new
                         instance is created, making each call self-contained.

    Returns:
        The final text response from the agent as a string. Returns
        "No final response from agent." if no final response event is found.
    """
    # Use the provided session service if available, otherwise create a new one.
    # This flexibility allows for both isolated examples and continuous conversations.
    if session_service is None:
        session_service = InMemorySessionService()

    # Create a new session. In a multi-turn conversation, you would reuse
    # the same session_id across turns to maintain context. 
    # For these distinct examples, we'll use unique session_ids.
    await session_service.create_session(app_name=app_name, user_id=user_id, session_id=session_id)

    # Format the user's input into a Content object, which is how messages
    # are structured for the agent.
    content = types.Content(role="user", parts=[types.Part(text=input_text)])

    # Initialize the Runner: This is the engine that connects the user's message
    # to the agent and manages the session state.
    runner = Runner(agent=agent, app_name=app_name, session_service=session_service)

    # Run the agent: This sends the user's message to the agent for processing.
    # The 'runner.run()' method returns an iterable of events that describe
    # the agent's actions and responses.
    events = runner.run(user_id=user_id, session_id=session_id, new_message=content)

    # Process the events to find and extract the final response from the agent.
    for event in events:
        if event.is_final_response():
            return event.content.parts[0].text
    return "No final response from agent."

print("Modular function `run_adk_agent_interaction` successfully defined.")

# # NOTE: More details about Runners, Sessions, and advanced event processing are coming up in later tutorials—stay tuned!
# Out:
# Modular function `run_adk_agent_interaction` successfully defined.

# %%
# Define common parameters for our interactions
APP_NAME = "adk_quickstart_app"
USER_ID = "test_user_001"
SESSION_ID = f"{APP_NAME}_session_001"

# Create a single instance of the session service.
# While `run_adk_agent_interaction` can create its own, passing a shared instance
# is slightly more efficient if you're running many interactions.
common_session_service = InMemorySessionService()

# Define a list of test cases for our greeting agent.
# Each dictionary contains the input text and a descriptive label.
test_cases = [
    {"label": "Spanish Greeting", "input": "Hola, ¿cómo estás?"},
    {"label": "English Greeting", "input": "Hello there! How are you doing today?"},
    {"label": "French Greeting", "input": "Bonjour! Comment allez-vous?"},
    {"label": "German Greeting", "input": "Guten Tag!"},
    {"label": "Non-greeting input (strict adherence test)", "input": "Can you tell me the capital of France?"},
    {"label": "Another non-greeting input", "input": "What time is it?"},
    {"label": "Mixed language but expecting primary", "input": "Hello, Bonjour!"}, # Should still pick up 'Hi!' as English
]

print("------ [starting agent interaction] ------\n")

# Iterate through each test case and run the agent interaction
for i, case in enumerate(test_cases):
    # Create a unique session ID for each test case to avoid AlreadyExistsError
    unique_session_id = f"{SESSION_ID}_{i}"
    response = await run_adk_agent_interaction(
        agent=greeting_agent,
        user_id=USER_ID,
        session_id=unique_session_id,
        input_text=case["input"],
        app_name=APP_NAME,
        session_service=common_session_service # Pass the shared service
    )
    
    print(f"Example {i+1}: {case['label']}")
    print(f"\tUser: {case['input']}")
    print(f"\tAgent: {response}\n")

print("\n------ [all agent interactions complete] ------")
# Out:
# ------ [starting agent interaction] ------
#
# Example 1: Spanish Greeting
# 	User: Hola, ¿cómo estás?
# 	Agent: ¡Hola! ¡Estoy muy bien, gracias por preguntar! ¡Qué gusto saludarte!
#
#
# Example 1: Spanish Greeting
# 	User: Hola, ¿cómo estás?
# 	Agent: ¡Hola! ¡Estoy muy bien, gracias por preguntar! ¡Qué gusto saludarte!
#
#
# Example 2: English Greeting
# 	User: Hello there! How are you doing today?
# 	Agent: Hello there! How are you doing today?!
#
#
# Example 2: English Greeting
# 	User: Hello there! How are you doing today?
# 	Agent: Hello there! How are you doing today?!
#
#
# Example 3: French Greeting
# 	User: Bonjour! Comment allez-vous?
# 	Agent: Bonjour! Comment allez-vous!
#
#
# Example 3: French Greeting
# 	User: Bonjour! Comment allez-vous?
# 	Agent: Bonjour! Comment allez-vous!
#
#
# Example 4: German Greeting
# 	User: Guten Tag!
# 	Agent: Guten Tag!
#
#
# Example 4: German Greeting
# 	User: Guten Tag!
# 	Agent: Guten Tag!
#
#
# Example 5: Non-greeting input (strict adherence test)
# 	User: Can you tell me the capital of France?
# 	Agent: Well hello there!
#
#
# Example 5: Non-greeting input (strict adherence test)
# 	User: Can you tell me the capital of France?
# 	Agent: Well hello there!
#
#
# Example 6: Another non-greeting input
# 	User: What time is it?
# 	Agent: Hello there!
#
#
# Example 6: Another non-greeting input
# 	User: What time is it?
# 	Agent: Hello there!
#
#
# Example 7: Mixed language but expecting primary
# 	User: Hello, Bonjour!
# 	Agent: Hello, Bonjour! I hope you are doing well!
#
#
#
# ------ [all agent interactions complete] ------
# Example 7: Mixed language but expecting primary
# 	User: Hello, Bonjour!
# 	Agent: Hello, Bonjour! I hope you are doing well!
#
#
#
# ------ [all agent interactions complete] ------

# %%
# Congratulations 🎉 Your First ADK Agent is Alive and Modular!
# Here's what you've achieved:
# Environment Setup: You've installed ADK and configured your environment to work with the Gemini model.
# Modular Design: You created a reusable function (run_adk_agent_interaction) to simplify agent invocations. This is a crucial step towards building complex multi-agent systems.
# Agent Definition: You defined an Agent and precisely controlled its behavior using the instruction parameter.
# Agent Interaction: You successfully sent various inputs to your agent and observed its responses, demonstrating its multilingual capability and adherence to its core instruction.
# This foundation prepares you for more advanced ADK concepts, such as integrating tools, managing complex conversational flows, and orchestrating multiple agents.
# More details about Runners, Sessions, and advanced event processing are coming up in later tutorials—stay tuned!
